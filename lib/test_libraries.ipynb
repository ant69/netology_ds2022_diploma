# %% [markdown]
# # Тестирование и отладка библиотек для работы с данными

# %%
# Загрузка блока инструкций для импорта библиотек из .py - файла
# %run "load_big_libs.py"

# %%
# Генерация словаря шаблонов протоколов в папке data/intermid
def init_project_dictionaries():
    templates_csv = '../data/external/protocols_templates.csv'
    df_templates = pd.read_csv(templates_csv, sep=';')
    df_templates['protocols_df_name'] = df_templates['code'].apply(lambda x: x.replace('П', 'protocols_').replace('.', '_'))
    df_tmpl = df_templates.set_index('code')
    return df_tmpl

# %%
# Инициализируем словарь шаблонов протоколов и смотрим, что получилось
df_templates = init_project_dictionaries()
df_templates.head()
# Out:
#       id                                              title  \
# code
# П1.1   1  Базовый протокол «Распределение внимания учителя»
# П1.2   3  Усложненный протокол «Распределение внимания у...
# П1.3   2  Прицельный протокол «Распределение внимания уч...
# П2.1   4            Базовый протокол «Время на размышление»
# П2.2   6        Усложненный протокол «Время на размышление»
#
#                                group  level protocols_df_name
# code
# П1.1  Распределение внимания учителя      1     protocols_1_1
# П1.2  Распределение внимания учителя      2     protocols_1_2
# П1.3  Распределение внимания учителя      3     protocols_1_3
# П2.1            Время на размышление      1     protocols_2_1
# П2.2            Время на размышление      2     protocols_2_2

# %%
# Функция позволяет загрузить все актуальные протоколы по проекту с сайта http://kurators.direktoria.org
# и сохранить протоколы каждого из проектов локально в папке data/external
# Одновременно инициализируются датасеты с протоколами по каждому из шаблонов
# В дальнейшем сохраненные версии датасетов могут скачиваться быстрее из локального хранилища
def load_protocols_data(df_templates):
    prot_mask_csv = 'http://kurators.direktoria.org/action.htm?action=export_data&do=get_template_protocols&filters=a:1:%7Bs:10:%22protocolId%22;s:%LEN_ID%:%22%ID%%22;%7D&format=csv&special=anonim'

    protocols_dfs = []

    for row in df_templates.iterrows():
        prot_id = str(row[1]['id'])
        prot_csv_link = prot_mask_csv.replace('%LEN_ID%', str(len(prot_id))).replace('%ID%', prot_id)
        print(f'Загружаем протокол {row[1]["title"]}')
        prot_df_name = row[1]['protocols_df_name']
        globals()[prot_df_name] = pd.read_csv(prot_csv_link, sep=';')
        globals()[prot_df_name].to_csv('../data/external/' + prot_df_name + '_raw.csv', sep=';')

# %%
# Функция позволяет загрузить ранее сохраненные "сырые" протоколы по проекту 
# Инициализируются датасеты с протоколами по каждому из шаблонов
def load_raw_protocols_data(df_templates):
    protocols_dfs = []

    for row in df_templates.iterrows():
        print(f'Загружаем протокол {row[1]["title"]}')
        prot_df_name = row[1]['protocols_df_name']
        globals()[prot_df_name] = pd.read_csv('../data/external/' + prot_df_name + '_raw.csv', sep=';')

# %%
load_protocols_data(df_templates)
# Out:
# Загружаем протокол Базовый протокол «Распределение внимания учителя»
# Загружаем протокол Усложненный протокол «Распределение внимания учителя»
# Загружаем протокол Прицельный протокол «Распределение внимания учителя»
# Загружаем протокол Базовый протокол «Время на размышление»
# Загружаем протокол Усложненный протокол «Время на размышление»
# Загружаем протокол Прицельный протокол «Время на размышление»
# Загружаем протокол Базовый протокол «Тип вопросов»
# Загружаем протокол Усложненный протокол «Тип вопросов»
# Загружаем протокол Прицельный протокол «Тип вопросов»
# Загружаем протокол Базовый протокол «Качество обратной связи»
# Загружаем протокол Усложненный протокол «Качество обратной связи»
# Загружаем протокол Прицельный протокол «Качество обратной связи»
# Загружаем протокол Базовый протокол «Время речи учеников»
# Загружаем протокол Усложненный протокол «Время речи учеников»
# Загружаем протокол Прицельный протокол «Время речи учеников»
# Загружаем протокол Базовый протокол «Правила речи»
# Загружаем протокол Усложненный протокол «Правила речи»
# Загружаем протокол Прицельный протокол «Правила речи»
# Загружаем протокол Базовый протокол «Время речи педагога»

# %%
#load_protocols_data(df_tmpl)
#print(df_templates.head())
#protocols_2_1.rename(columns = {'Unnamed: 0': 'protocol_id'}, inplace = True)
protocols_2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 55 columns):
#  #   Column                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                           --------------  -----
#  0   Id протокола                                                                                                                                     216 non-null    int64
#  1   Код шаблона                                                                                                                                      216 non-null    object
#  2   Название шаблона                                                                                                                                 216 non-null    object
#  3   Дата заполнения                                                                                                                                  216 non-null    object
#  4   Дата обсуждения                                                                                                                                  216 non-null    object
#  5   Id организации                                                                                                                                   216 non-null    int64
#  6   Название организации                                                                                                                             216 non-null    object
#  7   Id учителя                                                                                                                                       216 non-null    int64
#  8   ФИО учителя                                                                                                                                      216 non-null    object
#  9   Id наблюдателя                                                                                                                                   216 non-null    int64
#  10  ФИО наблюдателя                                                                                                                                  216 non-null    object
#  11  Id куратора                                                                                                                                      216 non-null    int64
#  12  ФИО куратора                                                                                                                                     216 non-null    object
#  13  Количество учеников на уроке                                                                                                                     216 non-null    int64
#  14  Сколько учеников из каждой группы было на уроке::Сильные                                                                                         216 non-null    int64
#  15  Сколько учеников из каждой группы было на уроке::Средние                                                                                         216 non-null    int64
#  16  Сколько учеников из каждой группы было на уроке::Слабые                                                                                          216 non-null    int64
#  17  Количество ответов на уроке                                                                                                                      216 non-null    int64
#  18  Количество ответов на уроке::Сильные                                                                                                             216 non-null    int64
#  19  Количество ответов на уроке::Средние                                                                                                             216 non-null    int64
#  20  Количество ответов на уроке::Слабые                                                                                                              216 non-null    int64
#  21  Количество отвечавших учеников                                                                                                                   216 non-null    int64
#  22  Сколько учеников из каждой группы отвечали::Сильные                                                                                              216 non-null    int64
#  23  Сколько учеников из каждой группы отвечали::Средние                                                                                              216 non-null    int64
#  24  Сколько учеников из каждой группы отвечали::Слабые                                                                                               216 non-null    int64
#  25  Время для размышления (пауза  сумма всех пауз) в секундах                                                                                        216 non-null    int64
#  26  Сколько всего времени дали на размышление (в секундах)::сильным                                                                                  216 non-null    int64
#  27  Сколько всего времени дали на размышление (в секундах)::средним                                                                                  216 non-null    int64
#  28  Сколько всего времени дали на размышление (в секундах)::слабым                                                                                   216 non-null    int64
#  29  Средняя длина паузы (в секундах)                                                                                                                 216 non-null    int64
#  30  Среднее время пауз (в секундах)::Сильные                                                                                                         216 non-null    int64
#  31  Среднее время пауз (в секундах)::Средние                                                                                                         216 non-null    int64
#  32  Среднее время пауз (в секундах)::Слабые                                                                                                          216 non-null    int64
#  33  Выводы и идеи (Вы удовлетворены? Нужно ли что-то изменить? Какую достижимую цель вы хотели бы себе поставить? Понимаете ли вы, как ее достичь?)  212 non-null    object
#  34  Unnamed: 34                                                                                                                                      0 non-null      float64
#  35  Ученики                                                                                                                                          216 non-null    int64
#  36  Сильные ученики %                                                                                                                                216 non-null    float64
#  37  Средние ученики %                                                                                                                                216 non-null    float64
#  38  Слабые ученики %                                                                                                                                 216 non-null    float64
#  39  Ответы                                                                                                                                           216 non-null    int64
#  40  Ответы сильных учеников %                                                                                                                        216 non-null    float64
#  41  Ответы средних учеников %                                                                                                                        216 non-null    float64
#  42  Ответы слабых учеников %                                                                                                                         216 non-null    float64
#  43  Отвечавшие ученики                                                                                                                               216 non-null    int64
#  44  Отвечавшие ученики %                                                                                                                             216 non-null    float64
#  45  Отвечавшие сильные ученики %                                                                                                                     216 non-null    float64
#  46  Отвечавшие средние ученики %                                                                                                                     216 non-null    float64
#  47  Отвечавшие слабые ученики %                                                                                                                      216 non-null    float64
#  48  Время размышления на один вопрос                                                                                                                 216 non-null    float64
#  49  Время размышления на один вопрос сильных учеников                                                                                                216 non-null    float64
#  50  Время размышления на один вопрос средних учеников                                                                                                216 non-null    float64
#  51  Время размышления на один вопрос слабых учеников                                                                                                 216 non-null    float64
#  52  Параллель класса                                                                                                                                 216 non-null    int64
#  53  Удовлетворенность уроком                                                                                                                         216 non-null    int64
#  54  Необходимость изменений                                                                                                                          216 non-null    int64
# dtypes: float64(15), int64(31), object(9)
# memory usage: 92.9+ KB

# %%
# Блок для тестирования функции загрузки протоколов из локального хранилища
# load_raw_protocols_data(df_tmpl)
# print(protocols_6_2.info())

# %% [markdown]
# ### Функция унификации датасетов по каждому из шаблонов протоколов
# - Очищенные от лишних данных датасеты сохраняются в папке data/intermid
# - Проводятся следующие преобразования:
# - Удаляются вторичные колонки
# - Удаляются личные данные
# - Заполняются дополнительные колонки с фиксированными названиями параметров.
# - Если данные для колонки отсутствуют, устанавливается значение NaN
#
# После унификации датасетов по каждому из шаблонов протоколов они могут быть объединены в единый датасет, который и будет далее использоваться для анализа.
#
# Общие мета-колонки для каждого протокола
# - prot_id (Id протокола)
# - template_code (Код шаблона)
# - date_of_lesson (Дата заполнения)
# - org_id (Id организации)
# - teacher_id (Id учителя, который провел урок)
# - observer_id (Id учителя, который наблюдал за уроком)
# - curator_id (Id куратора пары учителей)
#
# Колонки с данными
# - class (Параллель класса, в котором проводился урок. Число от 1 до 11)
# - satisfaction (Уровень удовлетворенности учителя проведенным уроком. Число от 1 до 4)
# - wish_to_change (Желание что-то изменить на следующих уроках. Число от 1 до 4)
#
# - pupils_all (Количество учеников на уроке)
# - pupils_strong (Количество сильных учеников на уроке)
# - pupils_middle (Количество средних учеников на уроке)
# - pupils_weak (Количество слабых учеников на уроке)
#
# - interactions_all (Количество взаимодействий с учениками на уроке)
# - interactions_strong (Количество взаимодействий с сильными учениками на уроке)
# - interactions_middle (Количество взаимодействий с средними учениками на уроке)
# - interactions_weak (Количество взаимодействий со слабыми учениками на уроке)
#
# - attention_all (Количество учеников, с которыми взаимодействовал учитель)
# - attention_strong (Количество сильных учеников, с которыми взаимодействовал учитель)
# - attention_middle (Количество средних учеников, с которыми взаимодействовал учитель)
# - attention_weak (Количество слабых учеников, с которыми взаимодействовал учитель)
#
# - teacher_comments ()

# %%
# Функция чистки датасетов по каждому из шаблонов протоколов 
# Очищенные от лишних данных датасеты сохраняются в папке data/intermid
# Проводятся следующие преобразования:
# Удаляются вторичные колонки
# Удаляются личные данные
# Заполняются дополнительные колонки с фиксированными названиями параметров.
# Если данные для колонки отсутствуют, устанавливается значение NaN

cols_substitutes = {
    'class': ['Параллель класса'],
    'satisfaction': ['Удовлетворенность уроком'],
    'wish_to_change': ['Необходимость изменений'],
    
    'pupils_all': ['Количество учеников на уроке'],
    'pupils_strong': ['Сколько учеников из каждой группы было на уроке::Сильные', 
                    'Количество учеников на уроке::Сильные'],
    'pupils_middle': ['Сколько учеников из каждой группы было на уроке::Средние', 
                    'Количество учеников на уроке::Средние'],
    'pupils_weak': ['Сколько учеников из каждой группы было на уроке::Слабые', 
                  'Количество учеников на уроке::Слабые'],

    'interactions_all': ['Количество ответов на уроке'],
    'interactions_strong': ['Сколько всего взаимодействий было с учениками::Сильные',
                           'Количество ответов на уроке::Сильные',
                           'Количество ответов на уроке от::Сильные'],
    'interactions_middle': ['Сколько всего взаимодействий было с учениками::Средние',
                           'Количество ответов на уроке::Средние',
                           'Количество ответов на уроке от::Средние'],
    'interactions_weak': ['Сколько всего взаимодействий было с учениками::Слабые',
                           'Количество ответов на уроке::Слабые',
                           'Количество ответов на уроке от::Слабые'],
    
    'attention_all': ['Количество отвечавших учеников'],
    'attention_strong': ['Сколько учеников были в зоне внимания учителя::Сильные',
                        'Сколько учеников из каждой группы отвечали::Сильные',
                        'Количество отвечавших учеников::Сильные'],
    'attention_middle': ['Сколько учеников были в зоне внимания учителя::Средние',
                        'Сколько учеников из каждой группы отвечали::Средние',
                        'Количество отвечавших учеников::Средние'],
    'attention_weak': ['Сколько учеников были в зоне внимания учителя::Слабые',
                        'Сколько учеников из каждой группы отвечали::Слабые',
                        'Количество отвечавших учеников::Слабые'],
    
    
    'teacher_comments': ['Выводы и идеи (Вы удовлетворены? Нужно ли что-то изменить? Какую достижимую цель вы хотели бы себе поставить? Понимаете ли вы, как ее достичь?)']
}   


def build_all_protocols_data(df_templates):
    dfs = []

    for row in df_templates.iterrows():
        print(f'Обрабатываем протокол {row[1]["title"]}')
        prot_df_name = row[1]['protocols_df_name']
        cols = ['Id протокола', 'Код шаблона', 'Дата заполнения', 'Id организации', 
                'Id учителя', 'Id наблюдателя', 'Id куратора']
        new_cols = ['prot_id', 'template_code', 'date_of_lesson', 'org_id', 
                    'teacher_id', 'observer_id', 'curator_id']
        df = globals()[prot_df_name].loc[:, cols]
        df.columns = new_cols
        for cs in cols_substitutes.items():
            old_col = pd.Series(np.nan)
            for raw_col in cs[1]:
                if raw_col in globals()[prot_df_name].columns:
                    old_col = globals()[prot_df_name][raw_col]
            df[cs[0]] = old_col        
        #df.set_index('prot_id', inplace=True)
        df.to_csv('../data/intermid/' + prot_df_name + '_stand.csv', sep=';')
        dfs.append(df)
        
    df_full = pd.concat(dfs, ignore_index=True)
    df_full.to_csv('../data/intermid/full_df_stand.csv', sep=';')  
    return df_full

# %%
df_protocols = build_all_protocols_data(df_templates)
# Out:
# Обрабатываем протокол Базовый протокол «Распределение внимания учителя»
# Обрабатываем протокол Усложненный протокол «Распределение внимания учителя»
# Обрабатываем протокол Прицельный протокол «Распределение внимания учителя»
# Обрабатываем протокол Базовый протокол «Время на размышление»
# Обрабатываем протокол Усложненный протокол «Время на размышление»
# Обрабатываем протокол Прицельный протокол «Время на размышление»
# Обрабатываем протокол Базовый протокол «Тип вопросов»
# Обрабатываем протокол Усложненный протокол «Тип вопросов»
# Обрабатываем протокол Прицельный протокол «Тип вопросов»
# Обрабатываем протокол Базовый протокол «Качество обратной связи»
# Обрабатываем протокол Усложненный протокол «Качество обратной связи»
# Обрабатываем протокол Прицельный протокол «Качество обратной связи»
# Обрабатываем протокол Базовый протокол «Время речи учеников»
# Обрабатываем протокол Усложненный протокол «Время речи учеников»
# Обрабатываем протокол Прицельный протокол «Время речи учеников»
# Обрабатываем протокол Базовый протокол «Правила речи»
# Обрабатываем протокол Усложненный протокол «Правила речи»
# Обрабатываем протокол Прицельный протокол «Правила речи»
# Обрабатываем протокол Базовый протокол «Время речи педагога»

# %%
df_protocols.describe(include = 'all')
# Out:
#             prot_id template_code date_of_lesson       org_id   teacher_id  \
# count   2973.000000          2973           2973  2973.000000  2973.000000
# unique          NaN            19            183          NaN          NaN
# top             NaN          П1.2     26.09.2022          NaN          NaN
# freq            NaN           278             44          NaN          NaN
# mean    1564.918264           NaN            NaN   102.654894   714.004709
# std      881.890611           NaN            NaN    23.745439   137.544724
# min       41.000000           NaN            NaN     1.000000   472.000000
# 25%      798.000000           NaN            NaN    87.000000   597.000000
# 50%     1561.000000           NaN            NaN   108.000000   721.000000
# 75%     2335.000000           NaN            NaN   121.000000   827.000000
# max     3083.000000           NaN            NaN   133.000000   970.000000
#
#         observer_id   curator_id        class  satisfaction  wish_to_change  \
# count   2973.000000  2973.000000  2973.000000   2973.000000     2973.000000
# unique          NaN          NaN          NaN           NaN             NaN
# top             NaN          NaN          NaN           NaN             NaN
# freq            NaN          NaN          NaN           NaN             NaN
# mean     714.048772   707.141608     1.558022      1.160108        0.674067
# std      137.640512   134.957220     2.813831      1.679761        1.136565
# min      472.000000   471.000000     0.000000      0.000000        0.000000
# 25%      597.000000   591.000000     0.000000      0.000000        0.000000
# 50%      721.000000   713.000000     0.000000      0.000000        0.000000
# 75%      827.000000   819.000000     2.000000      3.000000        1.000000
# max      970.000000   952.000000    11.000000      4.000000        4.000000
#
#         ...  pupils_weak  interactions_all  interactions_strong  \
# count   ...   2041.00000       1742.000000          1808.000000
# unique  ...          NaN               NaN                  NaN
# top     ...          NaN               NaN                  NaN
# freq    ...          NaN               NaN                  NaN
# mean    ...      3.11612         16.095293             4.474558
# std     ...      2.53867         20.134958             7.185071
# min     ...      0.00000          0.000000             0.000000
# 25%     ...      1.00000          0.000000             0.000000
# 50%     ...      3.00000         11.000000             0.000000
# 75%     ...      4.00000         25.000000             7.000000
# max     ...     28.00000        150.000000            56.000000
#
#         interactions_middle  interactions_weak  attention_all  \
# count           1808.000000        1808.000000    1928.000000
# unique                  NaN                NaN            NaN
# top                     NaN                NaN            NaN
# freq                    NaN                NaN            NaN
# mean               5.674779           3.548673       6.627075
# std                9.074212           6.480558       6.681379
# min                0.000000           0.000000       0.000000
# 25%                0.000000           0.000000       0.000000
# 50%                0.000000           0.000000       6.000000
# 75%                9.000000           5.000000      10.000000
# max               74.000000          76.000000     102.000000
#
#         attention_strong  attention_middle  attention_weak  teacher_comments
# count        2041.000000       2041.000000     2041.000000              2863
# unique               NaN               NaN             NaN              2693
# top                  NaN               NaN             NaN     удовлетворена
# freq                 NaN               NaN             NaN                 8
# mean            2.748163          3.529152        2.333170               NaN
# std             2.806204          3.067422        2.276634               NaN
# min             0.000000          0.000000        0.000000               NaN
# 25%             1.000000          2.000000        1.000000               NaN
# 50%             2.000000          3.000000        2.000000               NaN
# 75%             4.000000          5.000000        3.000000               NaN
# max            28.000000         31.000000       31.000000               NaN
#
# [11 rows x 23 columns]

# %%
# Получаем информацию по количеству протоколов для каждого из шаблонов
df_protocols.template_code.value_counts()
# Out:
# П1.2    278
# П3.2    243
# П2.2    216
# П4.2    201
# П1.3    190
# П3.3    183
# П1.1    182
# П3.1    173
# П2.3    168
# П4.1    166
# П2.1    148
# П4.3    143
# П5.2    131
# П6.2    112
# П5.3    102
# П5.1     95
# П6.1     91
# П7.1     77
# П6.3     74
# Name: template_code, dtype: int64

# %%
df_protocols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2973 entries, 0 to 2972
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   prot_id              2973 non-null   int64
#  1   template_code        2973 non-null   object
#  2   date_of_lesson       2973 non-null   object
#  3   org_id               2973 non-null   int64
#  4   teacher_id           2973 non-null   int64
#  5   observer_id          2973 non-null   int64
#  6   curator_id           2973 non-null   int64
#  7   class                2973 non-null   int64
#  8   satisfaction         2973 non-null   int64
#  9   wish_to_change       2973 non-null   int64
#  10  pupils_all           2973 non-null   int64
#  11  pupils_strong        2041 non-null   float64
#  12  pupils_middle        2041 non-null   float64
#  13  pupils_weak          2041 non-null   float64
#  14  interactions_all     1742 non-null   float64
#  15  interactions_strong  1808 non-null   float64
#  16  interactions_middle  1808 non-null   float64
#  17  interactions_weak    1808 non-null   float64
#  18  attention_all        1928 non-null   float64
#  19  attention_strong     2041 non-null   float64
#  20  attention_middle     2041 non-null   float64
#  21  attention_weak       2041 non-null   float64
#  22  teacher_comments     2863 non-null   object
# dtypes: float64(11), int64(9), object(3)
# memory usage: 534.3+ KB

# %%
df_protocols.head()
# Out:
#    prot_id template_code date_of_lesson  org_id  teacher_id  observer_id  \
# 0      816          П1.1     01.02.2022     133         726          725
# 1     1162          П1.1     02.02.2022     128         736          735
# 2     1170          П1.1     02.02.2022     128         735          736
# 3     1069          П1.1     04.02.2022     133         725          726
# 4      295          П1.1     07.02.2022      79         534          533
#
#    curator_id  class  satisfaction  wish_to_change  ...  pupils_weak  \
# 0         724      0             0               0  ...          NaN
# 1         734      0             0               0  ...          NaN
# 2         734      0             0               0  ...          NaN
# 3         724      0             0               0  ...          NaN
# 4         532      0             0               0  ...          NaN
#
#    interactions_all  interactions_strong  interactions_middle  \
# 0              30.0                  NaN                  NaN
# 1              18.0                  NaN                  NaN
# 2              17.0                  NaN                  NaN
# 3              39.0                  NaN                  NaN
# 4              18.0                  NaN                  NaN
#
#    interactions_weak  attention_all  attention_strong  attention_middle  \
# 0                NaN           10.0               NaN               NaN
# 1                NaN            6.0               NaN               NaN
# 2                NaN            9.0               NaN               NaN
# 3                NaN            9.0               NaN               NaN
# 4                NaN           11.0               NaN               NaN
#
#    attention_weak                                   teacher_comments
# 0             NaN  Больше внимания уделять слабым ученикам и моти...
# 1             NaN            Учитель  уделяет внимание всем учащимся
# 2             NaN  Уделять внимание не только тем, кто поднимает ...
# 3             NaN  Больше внимания уделять слабым ученикам и моти...
# 4             NaN  Своё внимание учитель  распределял на всех обу...
#
# [5 rows x 23 columns]

# %%
cols_substitutes = {
  'pupils_all': ['Количество учеников на уроке'],
  'pupils_strong': ['Сколько учеников из каждой группы было на уроке::Сильные', 
                    'Количество учеников на уроке::Сильные'],
  'pupils_middle': ['Сколько учеников из каждой группы было на уроке::Средние', 
                    'Количество учеников на уроке::Средние'],
  'pupils_weak': ['Сколько учеников из каждой группы было на уроке::Слабые', 
                  'Количество учеников на уроке::Слабые']
}  

cols = ['Id протокола', 'Код шаблона', 'Дата заполнения', 'Id организации', 'Id учителя', 'Id наблюдателя', 'Id куратора']
df_tmp = protocols_6_2.loc[:, cols]
df_tmp.columns = ['prot_id', 'template_code', 'date_of_lesson', 'org_id', 'teacher_id', 'observer_id', 'curator_id']
for cs in cols_substitutes.items():
    old_col = pd.Series(np.nan)
    for raw_col in cs[1]:
        if raw_col in protocols_6_2.columns:
            old_col = protocols_6_2[raw_col]
    df_tmp[cs[0]] = old_col        

df_tmp.head()
# Out:
#    prot_id template_code date_of_lesson  org_id  teacher_id  observer_id  \
# 0      162          П6.2     13.04.2022     111         796          795
# 1      166          П6.2     13.04.2022     111         795          796
# 2      426          П6.2     10.05.2022      98         632          633
# 3     1613          П6.2     11.05.2022     100         687          688
# 4     1209          П6.2     11.05.2022     128         735          736
#
#    curator_id  pupils_all  pupils_strong  pupils_middle  pupils_weak
# 0         794          19              6              8            5
# 1         794          19              7             10            2
# 2         631           3              0              2            1
# 3         689          18              6              8            4
# 4         734           9              4              3            2

# %%
#print(protocols_6_2.columns.get_loc('Unnamed'))
def drop_postproc_cols():
    unnamed_ind = False
    for col in protocols_6_2.columns:
        if 'Unnamed' in col:
            unnamed_ind = int(col.replace('Unnamed: ', ''))
            break;
    if unnamed_ind:
        cols = [x for x in range(unnamed_ind)]
        protocols_6_2_initial = protocols_6_2.iloc[:, cols]    
    else:
        protocols_6_2.copy()

#protocols_6_2_initial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 41 columns):
#  #   Column                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                           --------------  -----
#  0   Код шаблона                                                                                                                                      83 non-null     object
#  1   Название шаблона                                                                                                                                 83 non-null     object
#  2   Дата заполнения                                                                                                                                  83 non-null     object
#  3   Дата обсуждения                                                                                                                                  83 non-null     object
#  4   Название организации                                                                                                                             83 non-null     object
#  5   Id учителя                                                                                                                                       83 non-null     int64
#  6   ФИО учителя                                                                                                                                      83 non-null     object
#  7   Id наблюдателя                                                                                                                                   83 non-null     int64
#  8   ФИО наблюдателя                                                                                                                                  83 non-null     object
#  9   Id куратора                                                                                                                                      83 non-null     int64
#  10  ФИО куратора                                                                                                                                     83 non-null     object
#  11  Количество учеников на уроке                                                                                                                     83 non-null     int64
#  12  Количество учеников на уроке::Сильные                                                                                                            83 non-null     int64
#  13  Количество учеников на уроке::Средние                                                                                                            83 non-null     int64
#  14  Количество учеников на уроке::Слабые                                                                                                             83 non-null     int64
#  15  Количество отвечавших учеников                                                                                                                   83 non-null     int64
#  16  Количество отвечавших учеников::Сильные                                                                                                          83 non-null     int64
#  17  Количество отвечавших учеников::Средние                                                                                                          83 non-null     int64
#  18  Количество отвечавших учеников::Слабые                                                                                                           83 non-null     int64
#  19  Количество ответов на уроке::Сильные                                                                                                             83 non-null     int64
#  20  Количество ответов на уроке::Средние                                                                                                             83 non-null     int64
#  21  Количество ответов на уроке::Слабые                                                                                                              83 non-null     int64
#  22  Количество отвечавших, полностью выполнивших правило                                                                                             83 non-null     int64
#  23  Количество отвечавших, полностью выполнивших правило::Сильные                                                                                    83 non-null     int64
#  24  Количество отвечавших, полностью выполнивших правило::Средние                                                                                    83 non-null     int64
#  25  Количество отвечавших, полностью выполнивших правило::Слабые                                                                                     83 non-null     int64
#  26  Количество ответов с полностью выполненным правилом::Сильные                                                                                     83 non-null     int64
#  27  Количество ответов с полностью выполненным правилом::Средние                                                                                     83 non-null     int64
#  28  Количество ответов с полностью выполненным правилом::Слабые                                                                                      83 non-null     int64
#  29  Количество отвечавших, частично выполнивших правило                                                                                              83 non-null     int64
#  30  Количество отвечавших, частично выполнивших правило::Сильные                                                                                     83 non-null     int64
#  31  Количество отвечавших, частично выполнивших правило::Средние                                                                                     83 non-null     int64
#  32  Количество отвечавших, частично выполнивших правило::Слабые                                                                                      83 non-null     int64
#  33  Количество ответов с частично выполненным правилом::Сильные                                                                                      83 non-null     int64
#  34  Количество ответов с частично выполненным правилом::Средние                                                                                      83 non-null     int64
#  35  Количество ответов с частично выполненным правилом::Слабые                                                                                       83 non-null     int64
#  36  Количество отвечавших, от кого удалось добиться выполнения правила (из числа тех, у кого при первой попытке не получилось)                       83 non-null     int64
#  37  Количество отвечавших, от кого удалось добиться выполнения правила (из числа тех, у кого при первой попытке не получилось)::Сильные              83 non-null     int64
#  38  Количество отвечавших, от кого удалось добиться выполнения правила (из числа тех, у кого при первой попытке не получилось)::Средние              83 non-null     int64
#  39  Количество отвечавших, от кого удалось добиться выполнения правила (из числа тех, у кого при первой попытке не получилось)::Слабые               83 non-null     int64
#  40  Выводы и идеи (Вы удовлетворены? Нужно ли что-то изменить? Какую достижимую цель вы хотели бы себе поставить? Понимаете ли вы, как ее достичь?)  79 non-null     object
# dtypes: int64(32), object(9)
# memory usage: 26.7+ KB
