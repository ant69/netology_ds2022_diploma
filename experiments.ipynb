# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 18,8

# %%
series = pd.read_csv("organizations_stat_2.csv", sep=";")

# %%
series.head()
# Out:
#    Id организации                               Название организации  \
# 0           21499  МКОУ Березовская средняя общеобразовательная ш...
# 1           21500                   МБОУ Чановская средняя школа № 2
# 2           21501  МКОУ Таганаевская СОШ имени Героя Советского С...
# 3           21502   МКОУ Урезская основная общеобразовательная школа
# 4           21503  МКОУ Старощербаковская средняя общеобразовател...
#
#                         Руководитель              Старший куратор  \
# 0  Гусельникова Татьяна Владимировна   Барцинская Татьяна Юрьевна
# 1           Гинзбург Елена Сергеевна   Чурсина Людмила Николаевна
# 2           Ягошина Елена Николаевна    Исакова Тамара Викторовна
# 3        Петрова Оксана Владимировна       Гейдо Татьяна Петровна
# 4             Межуева Зоя Николаевна  Ростовцева Юлия Геннадьевна
#
#    Количество кураторов  Количество учителей  Все протоколы  \
# 0                     3                    8             43
# ...
